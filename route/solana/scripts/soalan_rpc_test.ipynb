# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
import time
# http_client = Client("https://api.devnet.solana.com")
# helius="https://devnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")

src_balance = http_client.get_balance(src_account.pubkey()).value
print("current src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("current dst balance:",dst_balance)

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
import time

helius="https://devnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")
delay_for_get_blockhash=2
delay_for_send_transaction=45
delay_for_tx_status=45
src_balance = http_client.get_balance(src_account.pubkey()).value
print("init src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("init dst balance:",dst_balance)
print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

time.sleep(delay_for_get_blockhash)

ixs = [
        sp.transfer(sp.TransferParams(from_pubkey=src_account.pubkey(), to_pubkey=dst_account, lamports=10000))
    ]
msg = Message.new_with_blockhash(ixs, src_account.pubkey(), blockhash)
transfer_tx = Transaction([src_account], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
time.sleep(delay_for_send_transaction)
resp = http_client.send_transaction(transfer_tx)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)
src_balance = http_client.get_balance(src_account.pubkey()).value
print("updated src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("updated dst balance:",dst_balance)

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solders.signature import Signature

import time
helius="https://devnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")

src_balance = http_client.get_balance(src_account.pubkey()).value
print("current src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("current dst balance:",dst_balance)

sigs=[Signature.from_string("5G77RXVm457aSvFyJdjd9befLWbFRhcp4k1XC9gGQuV1V8Ldj98TVZYfsYXBhiKHYhy8Qcj9qhUt8z2TDRWcEodJ")]
sig_state =http_client.get_signature_statuses(sigs,True)
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state.value)

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solana.rpc.types import  TxOpts
import time
# http_client = Client("https://api.devnet.solana.com")
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")
delay_for_get_blockhash=2
delay_for_send_transaction=15
delay_for_tx_status=10
src_balance = http_client.get_balance(src_account.pubkey()).value
print("init src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("init dst balance:",dst_balance)

print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
time.sleep(delay_for_get_blockhash)
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

ixs = [
        sp.transfer(sp.TransferParams(from_pubkey=src_account.pubkey(), to_pubkey=dst_account, lamports=1000))
    ]
msg = Message.new_with_blockhash(ixs, src_account.pubkey(), blockhash)
transfer_tx = Transaction([src_account], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
time.sleep(delay_for_send_transaction)

opts = TxOpts(skip_confirmation=False, skip_preflight = False)
resp = http_client.send_transaction(transfer_tx)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
time.sleep(delay_for_tx_status)
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)
src_balance = http_client.get_balance(src_account.pubkey()).value
print("updated src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("updated dst balance:",dst_balance)

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solders.signature import Signature

import time
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")

src_balance = http_client.get_balance(src_account.pubkey()).value
print("current src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("current dst balance:",dst_balance)

sigs=[Signature.from_string("4ScoXWrNvLzsCSS45TCpViAihEJo9vsPfYDr3sQaJ4V5RrupaEVgWwmPArhLqXdeHY74R1KzXiX9kT81pmKox8NF")]
sig_state =http_client.get_signature_statuses(sigs,True)
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state.value)
# Out:
# current src balance: 408428515
# current dst balance: 208972002
# signature status:  [TransactionStatus(
#     TransactionStatus {
#         slot: 298300872,
#         confirmations: None,
#         status: Ok(
#             (),
#         ),
#         err: None,
#         confirmation_status: Some(
#             Finalized,
#         ),
#     },
# )]

# %%
# alchemey mainet
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
import time
# http_client = Client("https://api.devnet.solana.com")
alchemy_m="https://solana-mainnet.g.alchemy.com/v2/t25IzpcIjBXhP-LOurqrTWLWmhPuBwsk"
http_client = Client(alchemy_m)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")
delay_for_get_blockhash=2
delay_for_send_transaction=50
delay_for_tx_status=10
src_balance = http_client.get_balance(src_account.pubkey()).value
print("init src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("init dst balance:",dst_balance)

print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
time.sleep(delay_for_get_blockhash)
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

ixs = [
        sp.transfer(sp.TransferParams(from_pubkey=src_account.pubkey(), to_pubkey=dst_account, lamports=1000))
    ]
msg = Message.new_with_blockhash(ixs, src_account.pubkey(), blockhash)
transfer_tx = Transaction([src_account], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
time.sleep(delay_for_send_transaction)

resp = http_client.send_transaction(transfer_tx)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
time.sleep(delay_for_tx_status)

http_client = Client(alchemy_m)
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)
src_balance = http_client.get_balance(src_account.pubkey()).value
print("updated src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("updated dst balance:",dst_balance)

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solders.signature import Signature

import time
alchemy_m="https://solana-mainnet.g.alchemy.com/v2/t25IzpcIjBXhP-LOurqrTWLWmhPuBwsk"
http_client = Client(alchemy_m)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")

src_balance = http_client.get_balance(src_account.pubkey()).value
print("current src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("current dst balance:",dst_balance)

sigs=[Signature.from_string("3GE3Wpim9zKtL8sWFQf1f8knVdSHn96QEgFsx5iDz4LXxzYP6hbWuESRbcqyHM3rqd8VdgfaCwpdUshBCb28Z5Fy")]
sig_state =http_client.get_signature_statuses(sigs,True)
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state.value)

# %%
# mint to
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solana.rpc.types import  TxOpts
from spl.token.client import Token
from spl.token.constants import ASSOCIATED_TOKEN_PROGRAM_ID, TOKEN_PROGRAM_ID
import spl.token.instructions as spl_token
import time
# http_client = Client("https://api.devnet.solana.com")
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
token_mint = Pubkey.from_string("9aBWuQ5dKG7T6vAaV9WgwTxTMUs3AjfNSgDEV8Pmw4Z2")
payer=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("9V5NxX9SbcXFfUZJU57QViDtXauwGrZBYfntnm54nzLA")
delay_for_get_blockhash=2
delay_for_send_transaction=10
delay_for_tx_status=15
amount=911111111

print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
time.sleep(delay_for_get_blockhash)
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

ixs = [
    spl_token.mint_to(
                spl_token.MintToParams(
                    program_id=TOKEN_PROGRAM_ID,
                    mint=token_mint,
                    dest=dst_account,
                    mint_authority=payer.pubkey(),
                    amount=amount,
                    signers=[],
                )
            )
    ]
msg = Message.new_with_blockhash(ixs, payer.pubkey(), blockhash)
txn = Transaction([payer], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
opts = TxOpts(skip_confirmation=False, skip_preflight = False)
time.sleep(delay_for_send_transaction)
resp = http_client.send_transaction(txn)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
time.sleep(delay_for_tx_status)
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)


# token_client= Token(http_client,token_mint,TOKEN_PROGRAM_ID,payer)
# time.sleep(delay_for_mint_to)
# resp=token_client.mint_to(dest=dst_account, mint_authority=payer, )
# print("mint_to result :",resp)
# resp = token_client.get_balance(dst_account)
# print("{} balance: {}".format(dst_account,resp))
# Out:
# mock delay 2s ,and get latest blockhash  ...
# latest block hash: HkSdNmnYd498ArykzsufJ9iXkSbsUYWpXEkxPwhhp7YB
# mock delay 10s ,and send transaction  ...
# send_transaction result: SendTransactionResp(Signature(3bQAH14c85k52EehAuqv7LmWdPaPDCCsfTbtH7n5Dz3d6qaWYNwE7m2cB1DtDXgSzYyhCJBb4kHRidR49Gy87pUo))
# mock delay 15s ,and get_signature_statuses  ...
# signature status:  GetSignatureStatusesResp { context: RpcResponseContext { slot: 298328387, api_version: Some("2.0.13") }, value: [Some(TransactionStatus(TransactionStatus { slot: 298328360, confirmations: Some(26), status: Ok(()), err: None, confirmation_status: Some(Confirmed) }))] }

# %%
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solders.signature import Signature

import time
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
src_account=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
dst_account=Pubkey.from_string("FDR2mUpiHKFonnwbUujLyhuNTt7LHEjZ1hDFX4UuCngt")

src_balance = http_client.get_balance(src_account.pubkey()).value
print("current src balance:",src_balance)
dst_balance = http_client.get_balance(dst_account).value
print("current dst balance:",dst_balance)

sigs=[Signature.from_string("3yDYTcxvTqRfZPxTMb9jSNFquH7pNPUXFJ5JfLs2HFnNitzxQa1sLA4mGxzivtykRiuaXPSn7DkQ4ie2mLxZWbGt")]
sig_state =http_client.get_signature_statuses(sigs,True)
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state.value)
# Out:
# current src balance: 408398715
# current dst balance: 208972002
# signature status:  [None]

# %%
# burn 
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solana.rpc.types import  TxOpts
from spl.token.client import Token
from spl.token.constants import ASSOCIATED_TOKEN_PROGRAM_ID, TOKEN_PROGRAM_ID
import spl.token.instructions as spl_token
import time
# http_client = Client("https://api.devnet.solana.com")
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
token_mint = Pubkey.from_string("9aBWuQ5dKG7T6vAaV9WgwTxTMUs3AjfNSgDEV8Pmw4Z2")
payer=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
burn_account=Pubkey.from_string("9V5NxX9SbcXFfUZJU57QViDtXauwGrZBYfntnm54nzLA")
delay_for_get_blockhash=2
delay_for_send_transaction=12
delay_for_tx_status=15
amount=1000


# token_client= Token(http_client,token_mint,TOKEN_PROGRAM_ID,payer)
# resp=token_client.burn(
#             account=burn_account,
#             owner=payer.pubkey(),
#             amount=amount)

# print("burn result :",resp)
# resp = token_client.get_balance(burn_account)
# print("{} balance: {}".format(burn_account,resp))

print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
time.sleep(delay_for_get_blockhash)
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

ixs = [ spl_token.burn(
                spl_token.BurnParams(
                    program_id=TOKEN_PROGRAM_ID,
                    account=burn_account,
                    mint=token_mint,
                    owner=payer.pubkey(),
                    amount=amount,
                    signers=[payer.pubkey()],
                )
            )
        ]
msg = Message.new_with_blockhash(ixs, payer.pubkey(), blockhash)
txn = Transaction([payer], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
opts = TxOpts(skip_confirmation=False, skip_preflight = False)
time.sleep(delay_for_send_transaction)
resp = http_client.send_transaction(txn)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
time.sleep(delay_for_tx_status)
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)

# %%
# transfer, burn and memo
from solana.rpc.api import Client
from solders.pubkey import Pubkey
from solders.keypair import Keypair
import solders.system_program as sp
from solders.message import MessageV0, Message
from solders.transaction import Transaction
from solana.rpc.types import  TxOpts
from spl.token.client import Token
from spl.token.constants import ASSOCIATED_TOKEN_PROGRAM_ID, TOKEN_PROGRAM_ID
import spl.token.instructions as spl_token
from spl.memo.instructions import MemoParams, create_memo
from spl.memo.constants import MEMO_PROGRAM_ID
from solana.rpc.commitment import Finalized

import time
# http_client = Client("https://api.devnet.solana.com")
helius="https://mainnet.helius-rpc.com/?api-key=174a6ec2-4439-4fca-9277-b12900c71fa5"
http_client = Client(helius)
payer=Keypair.from_bytes([143,19,100,3,213,252,67,197,16,73,65,76,72,33,185,112,213,36,134,228,109,178,41,136,115,0,195,206,234,57,232,7,39,225,234,201,93,212,181,14,64,235,184,190,89,114,47,55,181,221,51,224,26,7,109,81,138,175,218,14,149,236,48,99])
token_mint = Pubkey.from_string("9aBWuQ5dKG7T6vAaV9WgwTxTMUs3AjfNSgDEV8Pmw4Z2")
burn_account=Pubkey.from_string("9V5NxX9SbcXFfUZJU57QViDtXauwGrZBYfntnm54nzLA")
delay_for_get_blockhash=2
delay_for_send_transaction=12
delay_for_tx_status=15
transfer_amount=1000
burn_amount=1000
memo_msg="bc1qmh0chcr9f73a3ynt90k0w8qsqlydr4a6espnj6"

# token_client= Token(http_client,token_mint,TOKEN_PROGRAM_ID,payer)
# resp=token_client.burn(
#             account=burn_account,
#             owner=payer.pubkey(),
#             amount=amount)

# print("burn result :",resp)
# resp = token_client.get_balance(burn_account)
# print("{} balance: {}".format(burn_account,resp))

print("mock delay {}s ,and get latest blockhash  ...".format(delay_for_get_blockhash))
time.sleep(delay_for_get_blockhash)
blockhash = http_client.get_latest_blockhash().value.blockhash
print("latest block hash:",blockhash)

transfer_ix =sp.transfer(sp.TransferParams(from_pubkey=payer.pubkey(), to_pubkey=payer.pubkey(), lamports=1000))

burn_ix =spl_token.burn(
                spl_token.BurnParams(
                    program_id=TOKEN_PROGRAM_ID,
                    account=burn_account,
                    mint=token_mint,
                    owner=payer.pubkey(),
                    amount=burn_amount,
                    signers=[],
                )
            )
burn_checked_ix =spl_token.burn_checked(
                spl_token.BurnCheckedParams(
                    program_id=TOKEN_PROGRAM_ID,
                    mint=token_mint,
                    account=burn_account,
                    owner=payer.pubkey(),
                    amount=burn_amount,
                    decimals=0,
                    signers=[],
                )
            )
# Create memo params
memo_params = MemoParams(
        program_id=MEMO_PROGRAM_ID,
        signer=payer.pubkey(),
        message=bytes(memo_msg, encoding="utf8"),
    )
memo_ix=create_memo(memo_params)

ixs=[transfer_ix,burn_ix,burn_checked_ix,memo_ix]

msg = Message.new_with_blockhash(ixs, payer.pubkey(), blockhash)
txn = Transaction([payer], msg, blockhash)

print("mock delay {}s ,and send transaction  ...".format(delay_for_send_transaction))
opts = TxOpts(skip_confirmation=False, skip_preflight = False)
time.sleep(delay_for_send_transaction)
resp = http_client.send_transaction(txn)
print("send_transaction result:",resp)

print("mock delay {}s ,and get_signature_statuses  ...".format(delay_for_tx_status))
time.sleep(delay_for_tx_status)
sig_state =http_client.get_signature_statuses([resp.value])
# sig_state=http_client.confirm_transaction(resp.value).value
print("signature status: ",sig_state)

time.sleep(delay_for_tx_status)
tx = http_client.get_transaction(resp.value, commitment=Finalized, encoding="jsonParsed").value
print("tx detail: ",tx)
# Out:
# mock delay 2s ,and get latest blockhash  ...
# latest block hash: 58cojXXU3iPTS1i3Eo6HEYaZd7BX7WHJ2CHrLatB2Ga7
# mock delay 12s ,and send transaction  ...
# send_transaction result: SendTransactionResp(Signature(5MqBruFuLJDZvZE9qEPGPS2eUvBERceuTLBYoRckQuF1aQT8kDtzbA9HaLQ4CD4WzuDrZxf11aVowBqC7MyKMxY6))
# mock delay 15s ,and get_signature_statuses  ...
# signature status:  GetSignatureStatusesResp { context: RpcResponseContext { slot: 298472171, api_version: Some("2.0.13") }, value: [Some(TransactionStatus(TransactionStatus { slot: 298472151, confirmations: Some(12), status: Ok(()), err: None, confirmation_status: Some(Confirmed) }))] }
# ...
